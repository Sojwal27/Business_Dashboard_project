# %%
import pandas as pd

try:
    rf = pd.read_csv('/content/sample_data/final_cleaned_categories.csv')
except UnicodeDecodeError:
    rf = pd.read_csv('/content/sample_data/final_cleaned_categories.csv', encoding='latin-1')  # Or 'ISO-8859-1'

rf
# Out:
#                             Category
# 0                      Gas Companies
# 1                              Banks
# 2                    Grain Elevators
# 3                 Financial Services
# 4                    Fire Department
# ...                              ...
# 453534                  Art Supplies
# 453535                  Gift Baskets
# 453536                         Gifts
# 453537  Antique Repair & Restoration
# 453538                      Rv Parks
#
# [453539 rows x 1 columns]

# %%
# import pandas as pd

# # ... (your previous code to read the CSV) ...

# rf['Category'] = rf['Category'].astype('category')
# rf['Category'] = rf['Category'].cat.remove_unused_categories()

# %%
rf
# Out:
#                             Category
# 0                      Gas Companies
# 1                              Banks
# 2                    Grain Elevators
# 3                 Financial Services
# 4                    Fire Department
# ...                              ...
# 453534                  Art Supplies
# 453535                  Gift Baskets
# 453536                         Gifts
# 453537  Antique Repair & Restoration
# 453538                      Rv Parks
#
# [453539 rows x 1 columns]

# %%
# prompt: remove duplicate enteries in data

rf.drop_duplicates(subset=['Category'], inplace=True)
rf
# Out:
#                                              Category
# 0                                       Gas Companies
# 1                                               Banks
# 2                                     Grain Elevators
# 3                                  Financial Services
# 4                                     Fire Department
# ...                                               ...
# 451028  Cross Connection Control Testing & Inspection
# 451400               Manufactured Homes - Foundations
# 451483       Engravers Security Personal & Commercial
# 451508                Augers & Trenchers Manufacturer
# 452524                       Rennet Non Durable Goods
#
# [9376 rows x 1 columns]

# %%
rf.to_csv('cleaned_unique_categories.csv', index=False)
